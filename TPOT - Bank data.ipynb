# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("E:\\Projects folder\\Iris\\Avela.csv",header=None)

# %%
data.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.266074 -0.165620  0.320980  0.483299  0.172340  0.273364  0.371178
# 1  0.130292  0.870736 -3.210528  0.062493  0.261718  1.436060  1.465940
# 2 -0.116585  0.069915  0.068476 -0.783147  0.261718  0.439463 -0.081827
# 3  0.031541  0.297600 -3.210528 -0.583590 -0.721442 -0.307984  0.710932
# 4  0.229043  0.807926 -0.052442  0.082634  0.261718  0.148790  0.635431
#
#          7         8         9  10
# 0  0.929823  0.251173  0.159345  A
# 1  0.636203  0.282354  0.515587  A
# 2 -0.888236 -0.123005  0.582939  A
# 3  1.051693  0.594169 -0.533994  A
# 4  0.051062  0.032902 -0.086652  F

# %%
data.columns = [' intercolumnar distance ','upper margin ','lower margin ','exploitation ','row number',
               'modular ratio ','interlinear spacing','weight ','peak number','mod_ratio','class']

# %%
data.head()
# Out:
#     intercolumnar distance   upper margin   lower margin   exploitation   \
# 0                  0.266074      -0.165620       0.320980       0.483299
# 1                  0.130292       0.870736      -3.210528       0.062493
# 2                 -0.116585       0.069915       0.068476      -0.783147
# 3                  0.031541       0.297600      -3.210528      -0.583590
# 4                  0.229043       0.807926      -0.052442       0.082634
#
#    row number  modular ratio   interlinear spacing   weight   peak number  \
# 0    0.172340        0.273364             0.371178  0.929823     0.251173
# 1    0.261718        1.436060             1.465940  0.636203     0.282354
# 2    0.261718        0.439463            -0.081827 -0.888236    -0.123005
# 3   -0.721442       -0.307984             0.710932  1.051693     0.594169
# 4    0.261718        0.148790             0.635431  0.051062     0.032902
#
#    mod_ratio class
# 0   0.159345     A
# 1   0.515587     A
# 2   0.582939     A
# ...

# %%
data['class'].value_counts()
# Out:
# A    4286
# F    1961
# E    1095
# I     831
# X     522
# H     519
# G     446
# D     352
# Y     266
# C     103
# W      44
# B       5
# Name: class, dtype: int64

# %%
data_shuffle=data.iloc[np.random.permutation(len(data))]
data=data_shuffle.reset_index(drop=True)
data.head()
# Out:
#     intercolumnar distance   upper margin   lower margin   exploitation   \
# 0                 -0.141273      -0.244132       0.249852       0.593729
# 1                  0.377169       0.164129       0.139604      -0.241825
# 2                 -0.005490      -0.204876       0.320980      -0.694588
# 3                  0.648733      -0.197025       0.029355       0.335213
# 4                  0.216699       0.321153       0.128935       0.491087
#
#    row number  modular ratio   interlinear spacing   weight   peak number  \
# 0    0.261718       -0.474083            -0.006326  1.021425     0.095265
# 1    0.172340        2.058932             0.559930 -1.806469    -1.089631
# 2    0.261718       -0.474083            -0.119577 -0.581395    -0.278912
# 3   -0.185173       -1.346105            -0.987837  0.060828     0.469443
# 4    0.261718        0.439463             0.446679  0.230654    -0.278912
#
#    mod_ratio class
# 0  -0.308285     F
# 1   1.638727     A
# 2  -0.245429     F
# ...

# %%
data['class']=data['class'].map({'A':0,'F':1,'E':2,'I':3,'X':4,'H':5,'G':6,'D':7,'Y':8,'C':9,'W':10,'B':11})

data.head(20)
# Out:
#      intercolumnar distance   upper margin   lower margin   exploitation   \
# 0                  -0.141273      -0.244132       0.249852       0.593729
# 1                   0.377169       0.164129       0.139604      -0.241825
# 2                  -0.005490      -0.204876       0.320980      -0.694588
# 3                   0.648733      -0.197025       0.029355       0.335213
# 4                   0.216699       0.321153       0.128935       0.491087
# 5                   0.154980      -0.361900       0.409890      -0.171945
# 6                   0.117948      -0.212727       0.232070       0.807221
# 7                   0.093260      -0.055704       0.068476       0.305076
# 8                   0.093260      -0.267686       0.168055      -0.383884
# 9                   0.624046      -2.426761       0.178724       0.711352
# 10                  0.006853      -0.055704       0.335206       1.778897
# 11                  0.253730       0.219088       0.143160       0.720541
# ...

# %%
data_class = data['class'].values

# %%
pd.isnull(data).any()
# Out:
#  intercolumnar distance     False
# upper margin                False
# lower margin                False
# exploitation                False
# row number                  False
# modular ratio               False
# interlinear spacing         False
# weight                      False
# peak number                 False
# mod_ratio                   False
# class                       False
# dtype: bool

# %%
from sklearn.model_selection import train_test_split
training_indices, validation_indices = training_indices, testing_indices = train_test_split(data.index,
                                                                                            stratify = data_class,
                                                                                            train_size=0.75, test_size=0.25)

# %%
training_indices.size, validation_indices.size
# Out:
# (7822, 2608)

# %%
from tpot import TPOTClassifier
from tpot import TPOTRegressor

tpot = TPOTClassifier(generations=5,verbosity=2, population_size=20,
                      config_dict='TPOT MDR')

tpot.fit(data.drop('class',axis=1).loc[training_indices].values,
         data.loc[training_indices,'class'].values)

# %%
tpot.score(data.drop('class',axis=1).loc[validation_indices].values,
           data.loc[validation_indices, 'class'].values)

# %%
tpot = TPOTClassifier(verbosity=2, max_time_mins=2, max_eval_time_mins=0.04, population_size=15)
tpot.fit(data.drop('class',axis=1).loc[training_indices].values, data.loc[training_indices,'class'].values)

# %%
tpot.score(data.drop('class',axis=1).loc[validation_indices].values,
           data.loc[validation_indices, 'class'].values)

# %%
tpot = TPOTClassifier(verbosity=2, max_time_mins=2, max_eval_time_mins=0.04, population_size=20)
tpot.fit(data.drop('class',axis=1).loc[training_indices].values, data.loc[training_indices,'class'].values)

# %%
tpot.score(data.drop('class',axis=1).loc[validation_indices].values,
           data.loc[validation_indices, 'class'].values)
